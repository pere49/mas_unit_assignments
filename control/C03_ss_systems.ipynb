# %% [markdown]
# <hr>
# <center> Coding Exercise for Control Systems<br>
# <b> Exercise 3: State-Space Control Systems </b> <br>
# Prof. Dr. Florian Dörfler <br>
# Automatic Control Laboratory, ETH Zurich </center>
# <hr>

# %% [markdown]
# In this notebook, we learn about controllability of LTI systems.

# %% [markdown]
# <blockquote>
# <b>Activity:</b> Execute the code cells below so that the necessary libraries get imported.
# </blockquote>

# %%
# !pip install control

# %%
import numpy as np # the standard library for numerics, vectors, matrices
import control as ct # the standard library for basic operations for analysis and design of feedback control systems
import matplotlib.pyplot as plt # a comprehensive library for creating static, animated, and interactive visualizations
import scipy.linalg as slin # a library for linear algebra functions

# %% [markdown]
# <b> C 3.1: Analyzing controllability and uncontrollable subspaces </b>

# %% [markdown]
# Consider the continuous-time linear time-invariant system
# \begin{equation}
# \dot{x}(t) = Ax(t) + B u(t)=\begin{bmatrix} -1 & 2 & -3 & 0 \\ 0 & -2 & 6 & 4 \\ 0 & 0 & -4 & 4 \\ 0 & 0 & 0 & -6  \end{bmatrix} x(t) + \begin{bmatrix} 0 \\ 1 \\ 0 \\ 0 \end{bmatrix} u(t).
# \end{equation}

# %% [markdown]
# <blockquote>
# <b>Activity:</b> Complete the code fragment below to determine if the system is controllable.
# </blockquote>

# %%
# your code goes here

# %% [markdown]
# Next, we want to bring the system to the controllability staircase form to find out which states are controllable and which ones are not.

# %% [markdown]
# <blockquote>
# <b>Activity:</b>  Derive a transformation matrix $T$ with which you can bring the system to a controllability staircase form.
# </blockquote>

# %%
# your code goes here

# %% [markdown]
# <blockquote>
# <b>Activity:</b> Bring the system to the controllability staircase form. Is the system stabilizable?
# </blockquote>

# %%
# your code goes here
